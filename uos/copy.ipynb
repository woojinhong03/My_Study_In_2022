# %%
from sklearn.preprocessing import PolynomialFeatures 

poly = PolynomialFeatures(degree = 7, include_bias=False) #최고 차수를 5제곱까지 특성을 만든다.
poly.fit(X_train)
train_poly = poly.transform(X_train)
test_poly = poly.transform(X_test)
print(train_poly.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 4
#       1 from sklearn.preprocessing import PolynomialFeatures
#       3 poly = PolynomialFeatures(degree = 7, include_bias=False) #최고 차수를 5제곱까지 특성을 만든다.
# ----> 4 poly.fit(X_train)
#       5 train_poly = poly.transform(X_train)
#       6 test_poly = poly.transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(train_poly,y_train)
print(lr.score(train_poly,y_train))
print(lr.score(test_poly,y_test))
# Out:
# 0.7790553231644648
# 0.8118005131713042

# %%
#표준점수로 정규화
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(train_poly)
train_scaled = ss.transform(train_poly)
test_scaled = ss.transform(test_poly)

# %%
#릿지 회귀 규제
from sklearn.linear_model import Ridge
ridge = Ridge()

# %%
#최적의 alpha 값 찾기
import matplotlib.pyplot as plt
train_score = []
test_score = []

# %%
alpha_list = [0.1,1,10,100,1000] #10배씩 늘리기
for alpha in alpha_list:
    ridge = Ridge(alpha = alpha)
    ridge.fit(train_scaled, y_train)
    train_score.append(ridge.score(train_scaled, y_train))
    test_score.append(ridge.score(test_scaled, y_test))

# %%
plt.plot(train_score)
plt.plot(test_score)
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.show()

# %%
ridge = Ridge(alpha = 10)
ridge.fit(train_scaled, y_train)
print(ridge.score(train_scaled, y_train))
print(ridge.score(test_scaled, y_test))
# Out:
# 0.8436050249680646
# 0.8377812504083999

# %% [markdown]
# ※ Ridge regression : 0.8377812504083999

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()

# %%
train_score = []
test_score = []

alpha_list = [0.001,0.01,0.1,1,10] #10배씩 늘리기
for alpha in alpha_list:
    lasso = Lasso(alpha = alpha)
    lasso.fit(train_scaled, y_train)
    train_score.append(lasso.score(train_scaled, y_train))
    test_score.append(lasso.score(test_scaled, y_test))
# Out:
# c:\Users\wooji\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.424e+08, tolerance: 1.290e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\wooji\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.345e+08, tolerance: 1.290e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\wooji\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.409e+08, tolerance: 1.290e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\wooji\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.064e+08, tolerance: 1.290e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\wooji\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.483e+07, tolerance: 1.290e+06
#   model = cd_fast.enet_coordinate_descent(

# %%
plt.plot(train_score)
plt.plot(test_score)
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.show()

# %%
lasso = Lasso(alpha = 1)
lasso.fit(train_scaled, y_train)
print(lasso.score(train_scaled, y_train))
print(lasso.score(test_scaled, y_test))
# Out:
# 0.8422209536511481
# 0.8370787169488343
# c:\Users\wooji\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.064e+08, tolerance: 1.290e+06
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ※ Lasso regression : 0.8370787169488343

# %%
from sklearn.neighbors import KNeighborsRegressor
train_score = []
test_score = []
n_list = [i for i in range(1,10)]
for i in n_list:
    knr = KNeighborsRegressor(n_neighbors = i)
    knr.fit(X_train, y_train)
    train_score.append(knr.score(X_train, y_train))
    test_score.append(knr.score(X_test, y_test))

# %%
plt.plot(train_score)
plt.plot(test_score)
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.show()

# %%
knr.n_neighbors = 3
knr.fit(X_train, y_train)
print(knr.score(X_train, y_train))
print(knr.score(X_test, y_test))
# Out:
# 0.9150630837145229
# 0.8869280597210224

# %% [markdown]
# ※ KNeighbors Regressor : 0.8869280597210224

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(X_train)
train_scaled = ss.transform(X_train)
test_scaled = ss.transform(X_test)

# %%
from sklearn.linear_model import SGDRegressor
sg = SGDRegressor(max_iter=100,random_state=1, verbose=1)
sg.fit(train_scaled, y_train)
print(sg.score(train_scaled, y_train))
print(sg.score(test_scaled, y_test))
# Out:
# -- Epoch 1
# Norm: 2151.26, NNZs: 7, Bias: 5760.044834, T: 1056, Avg. loss: 5379770.436316
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 2445.42, NNZs: 7, Bias: 6180.465499, T: 2112, Avg. loss: 2205081.695646
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 2597.73, NNZs: 7, Bias: 6278.212311, T: 3168, Avg. loss: 2101652.538757
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 2685.09, NNZs: 7, Bias: 6257.470142, T: 4224, Avg. loss: 2070164.766003
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 2770.11, NNZs: 7, Bias: 6270.038997, T: 5280, Avg. loss: 2041667.590807
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 2842.81, NNZs: 7, Bias: 6246.457239, T: 6336, Avg. loss: 2032355.688195
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 2930.98, NNZs: 7, Bias: 6238.049876, T: 7392, Avg. loss: 2018699.990176
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 2974.77, NNZs: 7, Bias: 6230.237405, T: 8448, Avg. loss: 2014995.235118
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 3013.05, NNZs: 7, Bias: 6237.069536, T: 9504, Avg. loss: 2008410.636830
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 3036.96, NNZs: 7, Bias: 6251.273180, T: 10560, Avg. loss: 2003086.717831
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 3078.11, NNZs: 7, Bias: 6237.064422, T: 11616, Avg. loss: 2000364.844241
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 3102.69, NNZs: 7, Bias: 6239.450191, T: 12672, Avg. loss: 1995368.877551
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 3142.31, NNZs: 7, Bias: 6242.329821, T: 13728, Avg. loss: 1996562.174428
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 3162.52, NNZs: 7, Bias: 6258.731789, T: 14784, Avg. loss: 1993539.787131
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 3204.26, NNZs: 7, Bias: 6259.266486, T: 15840, Avg. loss: 1988531.734896
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 3208.52, NNZs: 7, Bias: 6249.774276, T: 16896, Avg. loss: 1990687.690077
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 3216.94, NNZs: 7, Bias: 6256.775470, T: 17952, Avg. loss: 1990013.856928
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 3248.42, NNZs: 7, Bias: 6246.652502, T: 19008, Avg. loss: 1987042.351522
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 3273.07, NNZs: 7, Bias: 6269.919356, T: 20064, Avg. loss: 1986238.647245
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 3271.76, NNZs: 7, Bias: 6265.676397, T: 21120, Avg. loss: 1988015.274156
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm:
# Norm: 3380.32, NNZs: 7, Bias: 6256.948336, T: 42240, Avg. loss: 1979351.779297
# Total training time: 0.01 seconds.
# -- Epoch 41
# Norm: 3381.53, NNZs: 7, Bias: 6248.806112, T: 43296, Avg. loss: 1979245.898472
# Total training time: 0.01 seconds.
# -- Epoch 42
# Norm: 3397.56, NNZs: 7, Bias: 6253.766412, T: 44352, Avg. loss: 1979538.604581
# Total training time: 0.01 seconds.
# -- Epoch 43
# Norm: 3385.23, NNZs: 7, Bias: 6249.028634, T: 45408, Avg. loss: 1979896.979710
# Total training time: 0.01 seconds.
# -- Epoch 44
# Norm: 3391.39, NNZs: 7, Bias: 6244.722859, T: 46464, Avg. loss: 1980601.427649
# Total training time: 0.01 seconds.
# -- Epoch 45
# Norm: 3387.94, NNZs: 7, Bias: 6241.983904, T: 47520, Avg. loss: 1979219.266031
# Total training time: 0.01 seconds.
# -- Epoch 46
# Norm: 3407.82, NNZs: 7, Bias: 6252.415468, T: 48576, Avg. loss: 1978940.094217
# Total training time: 0.01 seconds.
# -- Epoch 47
# Norm: 3403.53, NNZs: 7, Bias: 6258.971805, T: 49632, Avg. loss: 1979133.888590
# Total training time: 0.01 seconds.
# -- Epoch 48
# Norm: 3403.09, NNZs: 7, Bias: 6251.377984, T: 50688, Avg. loss: 1979714.453630
# Total training time: 0.01 seconds.
# -- Epoch 49
# Norm: 3406.18, NNZs: 7, Bias: 6249.846369, T: 51744, Avg. loss: 1977984.027556
# Total training time: 0.01 seconds.
# -- Epoch 50
# Norm: 3404.58, NNZs: 7, Bias: 6255.356138, T: 52800, Avg. loss: 1979680.773498
# Total training time: 0.01 seconds.
# -- Epoch 51
# Norm: 3409.58, NNZs: 7, Bias: 6260.909176, T: 53856, Avg. loss: 1979143.542084
# Total training time: 0.01 seconds.
# -- Epoch 52
# Norm: 3409.22, NNZs: 7, Bias: 6260.957926, T: 54912, Avg. loss: 1979360.992686
# Total training time: 0.01 seconds.
# -- Epoch 53
# Norm: 3414.17, NNZs: 7, Bias: 6254.790312, T: 55968, Avg. loss: 1979323.631831
# Total training time: 0.01 seconds.
# -- Epoch 54
# Norm: 3411.66, NNZs: 7, Bias: 6258.968687, T: 57024, Avg. loss: 1979009.265040
# Total training time: 0.01 seconds.
# Convergence after 54 epochs took 0.01 seconds
# 0.6773823786378116
# 0.7391836076701115

# %% [markdown]
# ※ SGD Regressor : 0.7391836076701115

# %%
from sklearn.tree import DecisionTreeRegressor 

dt = DecisionTreeRegressor(random_state=1)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10,10))
plot_tree(dt)
plt.show()

# %%
print(dt.score(X_train,y_train))
print(dt.score(X_test,y_test))
# Out:
# 1.0
# 0.8000469012915469

# %% [markdown]
# ※ DecisionTree Regressor : 0.8000469012915469
